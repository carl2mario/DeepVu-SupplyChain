# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (25, 9)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Loading csv file
df= pd.read_csv('clean_metal.csv')
df.head()
# Out:
#          Date       Price  f000_settle  f001_settle  f002_settle  f003_settle  \
# 0  2008-12-01  457.032497        56.29        51.91       0.6421        31.40
# 1  2008-12-02  465.530103        55.30        51.78       0.6354        30.77
# 2  2008-12-03  482.060575        55.21        51.21       0.6387        30.58
# 3  2008-12-04  472.395859        57.62        53.94       0.6413        29.50
# 4  2008-12-05  471.922241        56.75        53.58       0.6404        28.55
#
#    f004_settle  f005_settle  f006_settle  f007_settle     ...       \
# 0        31.83       1.4924       1.4938       348.75     ...
# 1        31.20       1.4895       1.4911       348.25     ...
# 2        30.98       1.4734       1.4757       348.25     ...
# 3        29.87       1.4746       1.4769       334.00     ...
# 4        28.93       1.4696       1.4717       309.25     ...
#
#    f128_settle  f129_settle  f130_settle  f131_settle  f132_settle  \
# ...

# %%
p1=df.copy()
p1.set_index('Date', inplace=True)
p1.head()
# Out:
#                  Price  f000_settle  f001_settle  f002_settle  f003_settle  \
# Date
# 2008-12-07  471.922241       56.750       53.580       0.6404       28.550
# 2008-12-14  467.806318       54.460       52.800       0.6569       30.920
# 2008-12-21  494.466420       47.350       46.530       0.6771       30.600
# 2008-12-28  500.461613       45.250       45.082       0.7198       32.880
# 2009-01-04  506.761893       42.732       40.914       0.6997       33.538
#
#             f004_settle  f005_settle  f006_settle  f007_settle  f008_settle  \
# Date
# 2008-12-07       28.930       1.4696       1.4717       309.25       319.25
# 2008-12-14       31.280       1.4948       1.4949       373.50       384.75
# 2008-12-21       30.910       1.4841       1.4842       380.75       391.00
# 2008-12-28       33.182       1.4650       1.4651       412.25       422.50
# 2009-01-04       33.880       1.4557       1.4554       407.00       417.75
#
# ...

# %%
p1.shape
# Out:
# (494, 139)

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split

# %%
p1.Price = p1.Price.shift(int(-0.3*p1.Price.size))

# %%
p1.tail()
# Out:
#             Price  f000_settle  f001_settle  f002_settle  f003_settle  \
# Date
# 2018-04-22    NaN       17.025       17.075       0.7668        31.30
# 2018-04-29    NaN       16.665       17.065       0.7580        30.61
# 2018-05-06    NaN       16.375       16.775       0.7536        30.77
# 2018-05-13    NaN       14.700       15.250       0.7544        31.31
# 2018-05-20    NaN       14.525       15.325       0.7511        30.98
#
#             f004_settle  f005_settle  f006_settle  f007_settle  f008_settle  \
# Date
# 2018-04-22       31.560       1.4055       1.4116       376.50       385.50
# 2018-04-29       30.808       1.3818       1.3879       394.90       402.70
# 2018-05-06       30.880       1.3567       1.3627       406.25       413.75
# 2018-05-13       31.420       1.3567       1.3626       396.50       405.00
# 2018-05-20       31.090       1.3499       1.3558       402.50       411.00
#
# ...

# %%
X = df.iloc[:,2:]
Y = df['Price']

# %%
X.head()
# Out:
#    f000_settle  f001_settle  f002_settle  f003_settle  f004_settle  \
# 0        56.29        51.91       0.6421        31.40        31.83
# 1        55.30        51.78       0.6354        30.77        31.20
# 2        55.21        51.21       0.6387        30.58        30.98
# 3        57.62        53.94       0.6413        29.50        29.87
# 4        56.75        53.58       0.6404        28.55        28.93
#
#    f005_settle  f006_settle  f007_settle  f008_settle  f009_settle  \
# 0       1.4924       1.4938       348.75       360.00       370.75
# 1       1.4895       1.4911       348.25       359.50       370.00
# 2       1.4734       1.4757       348.25       359.25       369.75
# 3       1.4746       1.4769       334.00       345.00       355.25
# 4       1.4696       1.4717       309.25       319.25       328.75
#
#       ...       f128_settle  f129_settle  f130_settle  f131_settle  \
# 0     ...             514.4        516.4      12545.0      12560.0
# ...

# %%
X_train = X.iloc[:int(-0.3*p1.Price.size),:]
X_test = X.iloc[int(-0.3*p1.Price.size):,:]
y_train = p1['Price'].iloc[:int(-0.3*p1.Price.size)]
y_test = p1['Price'].iloc[int(-0.3*p1.Price.size):]

# %%
print(X.shape)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2283, 138)
# (2135, 138)
# (346,)
# (148, 138)
# (148,)

# %%
X.head()
# Out:
#    f000_settle  f001_settle  f002_settle  f003_settle  f004_settle  \
# 0        56.29        51.91       0.6421        31.40        31.83
# 1        55.30        51.78       0.6354        30.77        31.20
# 2        55.21        51.21       0.6387        30.58        30.98
# 3        57.62        53.94       0.6413        29.50        29.87
# 4        56.75        53.58       0.6404        28.55        28.93
#
#    f005_settle  f006_settle  f007_settle  f008_settle  f009_settle  \
# 0       1.4924       1.4938       348.75       360.00       370.75
# 1       1.4895       1.4911       348.25       359.50       370.00
# 2       1.4734       1.4757       348.25       359.25       369.75
# 3       1.4746       1.4769       334.00       345.00       355.25
# 4       1.4696       1.4717       309.25       319.25       328.75
#
#       ...       f128_settle  f129_settle  f130_settle  f131_settle  \
# 0     ...             514.4        516.4      12545.0      12560.0
# ...

# %%
#X_train,X_test,y_train,y_test=train_test_split(X,Y, test_size=0.31)
#y_train.size

#test_score=lasso.score(X_test,y_test)

#print ("test score: ", test_score)

# %%
ridge = Ridge()
ridge.fit(X_train,y_train)
train_score=ridge.score(X_train,y_train)
coeff_used = np.sum(ridge.coef_!=0)
print ("training score:", train_score)
print ("number of features used: ", coeff_used)

ridge.predict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-b0990473ae50> in <module>()
#       1 ridge = Ridge()
# ----> 2 ridge.fit(X_train,y_train)
#       3 train_score=ridge.score(X_train,y_train)
#       4 coeff_used = np.sum(ridge.coef_!=0)
#       5 print ("training score:", train_score)
#
# ~\Anaconda3\envs\data-x\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     663         self : returns an instance of self.
#     664         """
# --> 665         return super(Ridge, self).fit(X, y, sample_weight=sample_weight)
#     666
#     667
#
# ~\Anaconda3\envs\data-x\lib\site-packages\sklearn\linear_model\ridge.py in fit(self, X, y, sample_weight)
#     481
#     482         X, y = check_X_y(X, y, ['csr', 'csc', 'coo'], dtype=_dtype,
# --> 483                          multi_output=True, y_numeric=True)
#     484
# ...

# %%
#X_train,X_test,y_train,y_test=train_test_split(X,Y, test_size=0.3)
#ridge = Ridge()
#ridge.fit(X_train,y_train)
#train_score=ridge.score(X_train,y_train)
#test_score=ridge.score(X_test,y_test)
#coeff_used = np.sum(ridge.coef_!=0)
print ("training score:", train_score)
#print ("test score: ", test_score)
print ("number of features used: ", coeff_used)

#ridge.predict

# %%
#a1=pd.DataFrame(lasso.predict(X))
#a1 = pd.DataFrame(ridge.predict(X_test))
#a1.head()

# %%
pylab.rcParams['figure.figsize'] = (25, 9)
plot(df.Price, color='blue')
plot(ridge.predict(X), color='red')
plt.grid()
plt.show

# %%
df.head()

# %%
df.Price=df.Price.shift(int(-0.3*df.Price.size))
a1=df.iloc[:,1:2]
a1.head()

# %%
a1['Predict']=pd.DataFrame(ridge.predict(X))
a1.index=df.index

# %%
#a1=df.iloc[:,1:2]
#a1.head()

# %%
a1.head()

# %%
#b=a1.iloc[int(2*len(a1)/3):len(a1)]
#b.head()

# %%
pylab.rcParams['figure.figsize'] = (25, 9)
plot(a1.Predict, color='blue')
plot(a1.Price, color='red')
plt.grid()
plt.show

# %%
def mean_absolute_percentage_error(test,predictions): 
    test = np.array(test)
    predictions = np.array(predictions)
    return np.mean(np.abs((test - predictions) / test)) * 100

# %%
b=a1.iloc[:int(2*len(a1)/3)]
mean_absolute_percentage_error(b.Price,b.Predict)
